# %% [markdown]
# <a href="https://colab.research.google.com/github/Caesar599/AluraStore/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %% [markdown]
# #1. Análisis de facturación

# %%
# Out:
#                                       0                   1     \
# Producto                 Asistente virtual     Mesa de comedor
# Categoría del Producto        Electrónicos             Muebles
# Precio                            164300.0            192300.0
# Costo de envío                      6900.0              8400.0
# Fecha de Compra                 16/01/2021          18/05/2022
# Vendedor                       Pedro Gomez     Beatriz Morales
# Lugar de Compra                     Bogotá            Medellín
# Calificación                             4                   1
# Método de pago          Tarjeta de crédito  Tarjeta de crédito
# Cantidad de cuotas                       8                   4
# lat                                4.60971             6.25184
# lon                              -74.08175           -75.56359
#
#                                       2                  3     \
# Producto                     Juego de mesa         Microondas
# Categoría del Producto            Juguetes  Electrodomésticos
# Precio                            209600.0           757500.0
# Costo de envío                     15900.0            41000.0
# Fecha de Compra                 15/03/2021         03/05/2022
# Vendedor                    Juan Fernandez     Juan Fernandez
# Lugar de Compra                  Cartagena               Cali
# Calificación                             1                  4
# Método de pago          Tarjeta de crédito              Nequi
# Cantidad de cuotas                       1                  1
# lat                               10.39972            3.43722
# lon                              -75.51444           -76.5225
#
#                                     4                        5     \
# Producto                Silla de oficina  Bloques de construcción
# Categoría del Producto           Muebles                 Juguetes
# Precio                          335200.0                  24200.0
# Costo de envío                   20200.0                      0.0
# Fecha de Compra               07/11/2020               03/12/2020
# Vendedor                   Maria Alfonso          Beatriz Morales
# Lugar de Compra                 Medellín                     Cali
# Calificación                           5                        5
# Método de pago                     Nequi                    Cupón
# Cantidad de cuotas                     1                        1
# lat                              6.25184                  3.43722
# lon                            -75.56359                 -76.5225
#
#                                   6                   7     \
# Producto                   Muñeca bebé        Lavavajillas
# Categoría del Producto        Juguetes   Electrodomésticos
# Precio                         44200.0           1189700.0
# Costo de envío                     0.0             63700.0
# Fecha de Compra             07/08/2021          18/06/2021
# Vendedor                Juan Fernandez       Felipe Santos
# Lugar de Compra                 Bogotá         Santa Marta
# Calificación                         3                   5
# Método de pago                   Nequi  Tarjeta de crédito
# Cantidad de cuotas                   1                  10
# lat                            4.60971            11.24079
# lon                          -74.08175           -74.19904
#
#                                       8                          9     ...  \
# Producto                  Lavadora de ropa  Carrito de control remoto  ...
# Categoría del Producto   Electrodomésticos                   Juguetes  ...
# Precio                           1518200.0                    75200.0  ...
# Costo de envío                     79000.0                     5100.0  ...
# Fecha de Compra                 08/01/2022                 24/02/2020  ...
# Vendedor                   Izabela de León            Beatriz Morales  ...
# Lugar de Compra                     Bogotá                     Bogotá  ...
# Calificación                             1                          5  ...
# Método de pago          Tarjeta de crédito                      Nequi  ...
# Cantidad de cuotas                       5                          1  ...
# lat                                4.60971                    4.60971  ...
# lon                              -74.08175                  -74.08175  ...
#
#                                            2349                       2350  \
# Producto                             Cubertería  Carrito de control remoto
# Categoría del Producto  Artículos para el hogar                   Juguetes
# Precio                                  35700.0                    68900.0
# Costo de envío                              0.0                     1900.0
# Fecha de Compra                      29/06/2020                 05/03/2023
# Vendedor                         Santiago Silva              Maria Alfonso
# Lugar de Compra                        Medellín                   Medellín
# Calificación                                  4                          5
# Método de pago                            Nequi                      Nequi
# Cantidad de cuotas                            1                          1
# lat                                     6.25184                    6.25184
# lon                                   -75.56359                  -75.56359
#
#                                       2351           2352  \
# Producto                  Silla de oficina      Cama king
# Categoría del Producto             Muebles        Muebles
# Precio                            489300.0       507900.0
# Costo de envío                     28400.0        32900.0
# Fecha de Compra                 10/12/2020     10/02/2021
# Vendedor                     Lucas Olivera  Rafael Acosta
# Lugar de Compra                     Bogotá       Medellín
# Calificación                             5              5
# Método de pago          Tarjeta de crédito          Nequi
# Cantidad de cuotas                       2              1
# lat                                4.60971        6.25184
# lon                              -74.08175      -75.56359
#
#                                            2353             2354  \
# Producto                             Cubertería        Iphone 15
# Categoría del Producto  Artículos para el hogar     Electrónicos
# Precio                                  40500.0        1284400.0
# Costo de envío                              0.0          66600.0
# Fecha de Compra                      30/12/2022       15/11/2021
# Vendedor                          Lucas Olivera  Izabela de León
# Lugar de Compra                          Bogotá         Medellín
# Calificación                                  5                1
# Método de pago               Tarjeta de crédito            Nequi
# Cantidad de cuotas                            1                1
# lat                                     4.60971          6.25184
# lon                                   -74.08175        -75.56359
#
#                                  2355                2356                2357  \
# Producto                    Impresora       Juego de mesa            Cama box
# Categoría del Producto   Electrónicos            Juguetes             Muebles
# Precio                       282800.0            122900.0            691300.0
# Costo de envío                15300.0              7200.0             35000.0
# Fecha de Compra            18/03/2023          06/07/2021          02/05/2022
# Vendedor                Lucas Olivera       Lucas Olivera         Pedro Gomez
# Lugar de Compra                Bogotá                Cali               Pasto
# Calificación                        5                   5                   1
# Método de pago                  Nequi  Tarjeta de crédito  Tarjeta de crédito
# Cantidad de cuotas                  1                   4                   2
# lat                           4.60971             3.43722             1.21361
# lon                         -74.08175            -76.5225           -77.28111
#
#                                       2358
# Producto                        Smartwatch
# Categoría del Producto        Electrónicos
# Precio                            195000.0
# Costo de envío                      8600.0
# Fecha de Compra                 18/06/2022
# Vendedor                     Felipe Santos
# Lugar de Compra                       Cali
# Calificación                             4
# Método de pago          Tarjeta de crédito
# Cantidad de cuotas                       1
# lat                                3.43722
# lon                               -76.5225
#
# [12 rows x 2359 columns]

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# # 5. Envío promedio por tienda
